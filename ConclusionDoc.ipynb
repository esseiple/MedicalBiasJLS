# %% [markdown]
# # Conclusion and Data Analysis

# %% [markdown]
# ## Notable Results:
#
# <u> Diabetes: </u>
#
# **Diabetes Race Risk**
#
# <img src="resultsImages/DiabetesRaceRisk.png" width="200">
#
# **Diabetes Gender Risk**
#
# <img src="resultsImages/DiabetesGenderRisk.png" width="200">
#
# **Diabetes Ethnicity Risk**
#
# <img src="resultsImages/DiabetesEthRisk.png" width="200">
#
# **Diabetes Current Address Risk**
#
# <img src="resultsImages/DiabetesAddRisk.png" width="400">
#
# ---
#
# <u> Pregnancy Issues: </u>
#
# **Pregnancy Race Risk**
#
# <img src="resultsImages/PregnancyRaceRisk.png" width="200">
#
# **Pregnancy Birthplace Risk**
#
# <img src="resultsImages/PregnancyBPRisk.png" width="400">
#
# **Pregnancy Current Address Risk**
#
# <img src="resultsImages/PregnancyAddRisk.png" width="400">
#
# ---
#
# <u> Cancer: </u>
#
# **Cancer Race Risk**
#
# <img src="resultsImages/CancerRaceRisk.png" width="200">
#
# **Cancer Gender Risk**
#
# <img src="resultsImages/CancerGenderRisk.png" width="200">
#
# **Cancer Birthplace Risk**
#
# <img src="resultsImages/CancerBPRisk.png" width="400">
#
# **Cancer Current Address Risk**
#
# <img src="resultsImages/CancerAddRisk.png" width="400">
#
# ---
#
# <u> Heart Issues </u>
#
# **Heart Race Risk**
#
# <img src="resultsImages/HeartRaceRisk.png" width="200">
#
# ---
#
# <u> Lungs Issues </u>
#
# **Lungs Ethnicity Risk**
#
# <img src="resultsImages/LungsEthRisk.png" width="200">
